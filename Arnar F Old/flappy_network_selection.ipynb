# %% [markdown]
# # Project imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd

import random
from datetime import datetime
import time

from fontTools.merge.util import current_time

# %%
import sys
import os
os.environ['SDL_VIDEODRIVER'] = 'dummy'
sys.path.insert(0, '../itml-project2')
# noinspection PyUnresolvedReferences
from ple.games.flappybird import FlappyBird
# noinspection PyUnresolvedReferences
from ple import PLE

# %%
class PPO_Flappy(nn.Module):

    def __init__(self,num_layers,layer_specs):
        super().__init__()

        self.layers = nn.ModuleList()
        for i in range(num_layers):
                self.layers.append(nn.Linear(layer_specs[i][0],layer_specs[i][1]))


        self.actor = nn.Linear(layer_specs[-1][1],2) # actor outputs a probability of jumping or doing nothing
        self.critic = nn.Linear(layer_specs[-1][1],1) # critic outputs value for state


    def forward(self,x):

        for i in self.layers:
            x = F.tanh(i(x))

        action_prob = F.softmax(self.actor(x),dim=-1) # return action probability
        state_value = self.critic(x) # Critic assessed state value
        return action_prob,state_value

# %% [markdown]
# # Helper Functions

# %%
def normalize_game_state(state):
    means = torch.tensor([256.0, 0.0, 200.0, 200.0, 200.0, 400.0, 200.0, 200.0])
    stds = torch.tensor([128.0, 5.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0])
    return (state - means) / stds

def create_network():
    total_layers = 3
    layer_specs = [[8, 256], [256, 256], [256, 256]]
    #layer_specs = [[8, 1024], [1024, 128], [128, 16], [16, 256], [256, 256]]
    return total_layers,layer_specs

def get_children():
    total_layers = 4
    input_layer = 8
    layer_specs = []
    layer_setup = [[8, 512], [512, 128], [128, 8], [8, 512]]

    layer_specs.append([input_layer,int(layer_setup[0][1]*2**(random.randint(-1,1)))])
    for i in range(total_layers-1):
        layer_specs.append([layer_specs[i][1],int(layer_setup[i+1][1]*2**(random.randint(-1,1)))])
    return total_layers,layer_specs

def get_random_layers():
    input_layer = 8
    total_layer_count = 5
    total_layers = random.randint(1, total_layer_count)
    layer_specs = []
    layer_specs.append([input_layer, 2 ** (3 + random.randint(1, 8))])

    for i in range(total_layers - 1):
        layer_specs.append([layer_specs[i][1], int(layer_specs[i][1]*2 ** (random.randint(-2, 2)))])

    total_size = 0
    for i in layer_specs:
        size = i[0]*i[1] + i[1]
        total_size += size

    print(f"Total Network Size: {total_size}")

    return total_layers, layer_specs

def get_Advantage(states,rewards):
    # Calculating Advantage

    # V(S_t)
    with torch.no_grad():
        _,prev_values = model(states)

    temp = torch.cat([prev_values, torch.zeros(1, 1)], dim=0)

    G = 0
    advantages = []
    t = len(rewards) - 1
    for _, reward in enumerate(reversed(rewards)):
        delta = reward + gamma * temp[t + 1] - temp[t]
        G = delta + lam * gamma * G
        advantages.insert(0, torch.FloatTensor([G]))
        t -= 1

    advantages = torch.stack(advantages)
    A = advantages.squeeze()

    returns = A + prev_values.squeeze()
    return A, returns

def train_print(epoch_num,L_clip_mean,L_vf_mean,L_entr_mean,avg_reward,elapsed_time):
    print(f"Epoch: {epoch_num}, "
              f"L_clip: {L_clip_mean:.2f}, "
              f"Squared loss: {L_vf_mean:.2f}, "
              f"Entropy loss: {L_entr_mean:.2f}, "
              f"Avg Rewards: {avg_reward:.2f}, "
              f"Time elapsed: {elapsed_time:.2f}s")

def get_model_names(total_models):
    """ Generate Model names"""
    identifier = [i for i in range(total_models)]

    unique_str = datetime.now().strftime("%d-%m-%Y ")

    names = ["flappy weights/Flappy " + str(unique_str)+str(i) + ".pt" for i in identifier]
    return names

# %% [markdown]
# # training Loop

# %%
def Train_Network(epochs,print_freq):

    start_time = time.time()
    game = FlappyBird()

    total_rewards = []
    all_L_clip = []
    all_L_vf = []
    all_L_entropy = []
    stats_rows = []

    for i in range(epochs):
        done = False
        p = PLE(game, fps=30, display_screen=False, force_fps=True)
        p.init()

        log_probs = []
        rewards = []
        states = []
        actions = []

        while not done:
            game_state = normalize_game_state(torch.tensor(list(p.getGameState().values())))

            action_prob,_ = model(game_state) # get action prob from model, critic values called later

            # Actor Action
            action_prob = action_prob.detach().squeeze()
            dist = torch.distributions.Categorical(action_prob)
            action = dist.sample()

            if action == 0:
                ret_action = p.getActionSet()[0]
            else:
                ret_action = p.getActionSet()[1]

            # Acting on environment
            reward = p.act(ret_action)

            # Saving values
            log_probs.append(dist.log_prob(action))
            rewards.append(reward)
            actions.append(action)
            states.append(game_state)

            #print_state(action,state,reward)
            if p.game_over():
                done = True
                p.reset_game()


        # Storing values after game loop
        total_rewards.append(sum(rewards))
        states = torch.stack(states).squeeze()
        log_probs = torch.stack(log_probs).squeeze()
        actions = torch.stack(actions).squeeze()
        # Calculating advantage and storing returns for later
        A, returns = get_Advantage(states,rewards)


        for j in range(K_epochs):

            action_probs,new_values = model(states) # Generate new actions and values
            new_dist = torch.distributions.Categorical(action_probs) # Create distribution from new actions probs
            new_policy = new_dist.log_prob(actions) # New policy probs of prev actions

            ratio = torch.exp(new_policy-log_probs) # Ratio of new vs prev policy
            clipped_ratio = torch.clamp(ratio,min = 1-epsilon,max= 1+epsilon) # Ratio most stay between 1 +- eps

            L_clip = (torch.min(ratio*A,clipped_ratio*A).mean())*c0 # We select the ratio if between clip range else clipped ratio
            L_vf = ((new_values.squeeze() - returns.squeeze())**2)*c1 # Calculate squared loss
            entropy_bonus = (new_dist.entropy())*c2 # Getting entropy bonus for loss

            loss = -(L_clip-L_vf+entropy_bonus).mean()

            all_L_clip.append(L_clip.mean().item())
            all_L_vf.append(L_vf.mean().item())
            all_L_entropy.append(entropy_bonus.mean().item())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        epoch_L_clip = sum(all_L_clip[-K_epochs:]) / K_epochs
        epoch_L_vf = sum(all_L_vf[-K_epochs:]) / K_epochs
        epoch_L_entropy = sum(all_L_entropy[-K_epochs:]) / K_epochs
        stats_rows.append({
            "epoch": i + 1,
            "reward": total_rewards[-1],
            "L_clip": epoch_L_clip,
            "L_vf": epoch_L_vf,
            "L_entropy": epoch_L_entropy,
        })

        if (i+1) < 1500:
            print_freq = 100
        else:
            print_freq = 10

        if (i+1) % print_freq == 0:
            current_time = time.time()
            elapsed_time = current_time - start_time

            epoch_num = i+1
            n_recent = int(K_epochs*print_freq)

            avg_reward = sum(total_rewards[-print_freq:]) /len(total_rewards[-print_freq:])
            L_clip_mean = sum(all_L_clip[-n_recent:]) / len(all_L_clip[-n_recent:])
            L_vf_mean = sum(all_L_vf[-n_recent:]) / len(all_L_vf[-n_recent:])
            L_entr_mean = sum(all_L_entropy[-n_recent:]) / len(all_L_entropy[-n_recent:])

            train_print(epoch_num,L_clip_mean,L_vf_mean,L_entr_mean,avg_reward,elapsed_time)

    return pd.DataFrame(stats_rows)

# %% [markdown]
# ### Hyper paramters

# %%
from datetime import datetime

lr = 0.0001 # Learning Rate
epsilon = 0.1 # Clipping range
gamma = 0.99 # Reward discount factor
lam = 0.95

# Loss Coeffs
c0 = 1
c1 = 0.0001
c2 = 0.01

# %% [markdown]
# # Train

# %%
Total_runs = 3
epochs = 2500
K_epochs = 5
print_freq = 10
model_dict = {}


for i in range(Total_runs):
    total_layers,layer_specs = create_network()
    print("Total layers: ",total_layers)
    print(f"Layer setup: {layer_specs}")

    model = PPO_Flappy(total_layers,layer_specs)
    optimizer = torch.optim.Adam(model.parameters(),lr = lr)

    stats = Train_Network(epochs,print_freq)

    # Saving model weights
    #model_name = model_names[i]
    #torch.save(model.state_dict(),model_name)
# Out:
# Total layers:  3
# Layer setup: [[8, 1024], [1024, 512], [512, 2048]]
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Epoch: 100, L_clip: -0.83, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.87, Time elapsed: 3.53s
# Epoch: 200, L_clip: -0.37, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.81, Time elapsed: 7.07s
# Epoch: 300, L_clip: -0.17, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.82, Time elapsed: 10.66s
# Epoch: 400, L_clip: -0.14, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.73, Time elapsed: 14.91s
# Epoch: 500, L_clip: -0.13, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.81, Time elapsed: 18.75s
# Epoch: 600, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.83, Time elapsed: 22.40s
# Epoch: 700, L_clip: -0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.82, Time elapsed: 26.08s
# Epoch: 800, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.67, Time elapsed: 30.03s
# Epoch: 900, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.13, Time elapsed: 34.80s
# Epoch: 1000, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -2.64, Time elapsed: 41.02s
# Epoch: 1100, L_clip: -0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 1.09, Time elapsed: 51.59s
# Epoch: 1200, L_clip: 0.12, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 13.42, Time elapsed: 75.72s
# Epoch: 1300, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 25.64, Time elapsed: 112.80s
# Epoch: 1400, L_clip: -0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 10.34, Time elapsed: 133.01s
# Epoch: 1500, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 18.40, Time elapsed: 165.16s
# Epoch: 1510, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 14.90, Time elapsed: 167.73s
# Epoch: 1520, L_clip: 0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 22.70, Time elapsed: 171.16s
# Epoch: 1530, L_clip: -0.26, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 6.10, Time elapsed: 172.74s
# Epoch: 1540, L_clip: 0.13, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 7.40, Time elapsed: 174.53s
# Epoch: 1550, L_clip: -0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 15.10, Time elapsed: 177.08s
# Epoch: 1560, L_clip: 0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 19.40, Time elapsed: 180.12s
# Epoch: 1570, L_clip: 0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 33.70, Time elapsed: 184.68s
# Epoch: 1580, L_clip: 0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 60.10, Time elapsed: 192.16s
# Epoch: 1590, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 29.60, Time elapsed: 196.30s
# Epoch: 1600, L_clip: 0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 71.30, Time elapsed: 204.84s
# Epoch: 1610, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 26.40, Time elapsed: 208.63s
# Epoch: 1620, L_clip: 0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 20.30, Time elapsed: 211.75s
# Epoch: 1630, L_clip: -0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 15.50, Time elapsed: 214.43s
# Epoch: 1640, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 36.80, Time elapsed: 219.36s
# Epoch: 1650, L_clip: -0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 48.10, Time elapsed: 225.39s
# Epoch: 1660, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 56.90, Time elapsed: 232.48s
# Epoch: 1670, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 74.60, Time elapsed: 241.44s
# Epoch: 1680, L_clip: 0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 100.60, Time elapsed: 253.26s
# Epoch: 1690, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 159.20, Time elapsed: 271.30s
# Epoch: 1700, L_clip: -0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 69.80, Time elapsed: 279.81s
# Epoch: 1710, L_clip: -0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 27.60, Time elapsed: 283.73s
# Epoch: 1720, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 96.40, Time elapsed: 295.67s
# Epoch: 1730, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 77.30, Time elapsed: 305.69s
# Epoch: 1740, L_clip: -0.12, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 80.90, Time elapsed: 315.49s
# Epoch: 1750, L_clip: 0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 63.00, Time elapsed: 323.45s
# Epoch: 1760, L_clip: -0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 36.00, Time elapsed: 328.32s
# Epoch: 1770, L_clip: 0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 29.90, Time elapsed: 332.50s
# Epoch: 1780, L_clip: 0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 115.10, Time elapsed: 345.86s
# Epoch: 1790, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 29.20, Time elapsed: 349.96s
# Epoch: 1800, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 17.40, Time elapsed: 352.80s
# Epoch: 1810, L_clip: -0.34, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 9.50, Time elapsed: 354.70s
# Epoch: 1820, L_clip: 0.13, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 11.40, Time elapsed: 356.83s
# Epoch: 1830, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 21.10, Time elapsed: 360.03s
# Epoch: 1840, L_clip: 0.17, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 68.70, Time elapsed: 368.33s
# Epoch: 1850, L_clip: 0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 92.40, Time elapsed: 379.21s
# Epoch: 1860, L_clip: -0.13, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 26.10, Time elapsed: 382.93s
# Epoch: 1870, L_clip: 0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 38.20, Time elapsed: 388.03s
# Epoch: 1880, L_clip: -0.14, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 25.30, Time elapsed: 391.69s
# Epoch: 1890, L_clip: 0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 18.60, Time elapsed: 394.60s
# Epoch: 1900, L_clip: -0.22, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 4.20, Time elapsed: 395.97s
# Epoch: 1910, L_clip: -0.35, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -1.20, Time elapsed: 396.75s
# Epoch: 1920, L_clip: 0.12, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 9.90, Time elapsed: 398.73s
# Epoch: 1930, L_clip: 0.21, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 29.10, Time elapsed: 402.83s
# Epoch: 1940, L_clip: 0.13, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 31.90, Time elapsed: 407.17s
# Epoch: 1950, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 34.20, Time elapsed: 411.83s
# Epoch: 1960, L_clip: 0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 27.00, Time elapsed: 415.67s
# Epoch: 1970, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 27.60, Time elapsed: 419.54s
# Epoch: 1980, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 41.20, Time elapsed: 424.88s
# Epoch: 1990, L_clip: 0.13, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 50.10, Time elapsed: 431.29s
# Epoch: 2000, L_clip: 0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 35.60, Time elapsed: 436.07s
# Epoch: 2010, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 57.90, Time elapsed: 443.18s
# Epoch: 2020, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 38.50, Time elapsed: 448.32s
# Epoch: 2030, L_clip: 0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 51.10, Time elapsed: 454.77s
# Epoch: 2040, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 55.60, Time elapsed: 461.75s
# Epoch: 2050, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 14.50, Time elapsed: 464.22s
# Epoch: 2060, L_clip: 0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 61.20, Time elapsed: 471.77s
# Epoch: 2070, L_clip: -0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 47.10, Time elapsed: 477.79s
# Epoch: 2080, L_clip: -0.15, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 10.60, Time elapsed: 479.84s
# Epoch: 2090, L_clip: -0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 17.60, Time elapsed: 482.67s
# Epoch: 2100, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 18.10, Time elapsed: 485.53s
# Epoch: 2110, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 60.10, Time elapsed: 492.93s
# Epoch: 2120, L_clip: 0.18, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 65.00, Time elapsed: 500.90s
# Epoch: 2130, L_clip: 0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 73.40, Time elapsed: 509.72s
# Epoch: 2140, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 22.80, Time elapsed: 513.17s
# Epoch: 2150, L_clip: 0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 26.80, Time elapsed: 516.96s
# Epoch: 2160, L_clip: 0.10, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 117.90, Time elapsed: 530.59s
# Epoch: 2170, L_clip: -0.19, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 19.90, Time elapsed: 533.65s
# Epoch: 2180, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 29.00, Time elapsed: 537.68s
# Epoch: 2190, L_clip: -0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 18.70, Time elapsed: 540.65s
# Epoch: 2200, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 13.80, Time elapsed: 543.07s
# Epoch: 2210, L_clip: 0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 41.90, Time elapsed: 548.52s
# Epoch: 2220, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 35.90, Time elapsed: 553.36s
# Epoch: 2230, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 24.30, Time elapsed: 556.91s
# Epoch: 2240, L_clip: 0.12, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 57.40, Time elapsed: 564.06s
# Epoch: 2250, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 44.10, Time elapsed: 569.74s
# Epoch: 2260, L_clip: 0.12, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 75.10, Time elapsed: 578.70s
# Epoch: 2270, L_clip: 0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 78.60, Time elapsed: 588.18s
# Epoch: 2280, L_clip: 0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 113.20, Time elapsed: 601.28s
# Epoch: 2290, L_clip: 0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 67.80, Time elapsed: 609.54s
# Epoch: 2300, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 54.60, Time elapsed: 616.29s
# Epoch: 2310, L_clip: -0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 74.10, Time elapsed: 625.15s
# Epoch: 2320, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 26.90, Time elapsed: 628.96s
# Epoch: 2330, L_clip: -0.15, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 0.00, Time elapsed: 629.87s
# Epoch: 2340, L_clip: 0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 4.00, Time elapsed: 631.23s
# Epoch: 2350, L_clip: -0.22, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 2.20, Time elapsed: 632.38s
# Epoch: 2360, L_clip: 0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 5.60, Time elapsed: 633.89s
# Epoch: 2370, L_clip: -0.15, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 13.90, Time elapsed: 636.35s
# Epoch: 2380, L_clip: -0.16, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 0.70, Time elapsed: 637.31s
# Epoch: 2390, L_clip: 0.18, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 9.20, Time elapsed: 639.19s
# Epoch: 2400, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 16.10, Time elapsed: 641.84s
# Epoch: 2410, L_clip: 0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 23.70, Time elapsed: 645.30s
# Epoch: 2420, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 7.80, Time elapsed: 647.06s
# Epoch: 2430, L_clip: 0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 21.70, Time elapsed: 650.41s
# Epoch: 2440, L_clip: 0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 29.90, Time elapsed: 654.55s
# Epoch: 2450, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 19.70, Time elapsed: 657.59s
# Epoch: 2460, L_clip: -0.10, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 13.40, Time elapsed: 659.96s
# Epoch: 2470, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 11.10, Time elapsed: 662.09s
# Epoch: 2480, L_clip: 0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 23.90, Time elapsed: 665.59s
# Epoch: 2490, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 29.60, Time elapsed: 669.74s
# Epoch: 2500, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 14.60, Time elapsed: 672.22s
# Total layers:  3
# Layer setup: [[8, 1024], [1024, 512], [512, 2048]]
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Epoch: 100, L_clip: -0.85, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.85, Time elapsed: 3.71s
# Epoch: 200, L_clip: -0.24, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.85, Time elapsed: 7.41s
# Epoch: 300, L_clip: -0.14, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.59, Time elapsed: 11.40s
# Epoch: 400, L_clip: -0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.45, Time elapsed: 15.59s
# Epoch: 500, L_clip: -0.14, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.53, Time elapsed: 19.62s
# Epoch: 600, L_clip: -0.14, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.95, Time elapsed: 23.23s
# Epoch: 700, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.80, Time elapsed: 27.04s
# Epoch: 800, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.51, Time elapsed: 31.15s
# Epoch: 900, L_clip: -0.05, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.79, Time elapsed: 35.02s
# Epoch: 1000, L_clip: -0.03, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.86, Time elapsed: 38.92s
# Epoch: 1100, L_clip: -0.06, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.92, Time elapsed: 42.53s
# Epoch: 1200, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.96, Time elapsed: 46.32s
# Epoch: 1300, L_clip: 0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.99, Time elapsed: 50.15s
# Epoch: 1400, L_clip: -0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.98, Time elapsed: 54.13s
# Epoch: 1500, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.70, Time elapsed: 58.29s
# Epoch: 1510, L_clip: -0.06, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -5.00, Time elapsed: 58.68s
# Epoch: 1520, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -5.00, Time elapsed: 59.06s
# Epoch: 1530, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.70, Time elapsed: 59.50s
# Epoch: 1540, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -5.00, Time elapsed: 59.90s
# Epoch: 1550, L_clip: 0.07, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.50, Time elapsed: 60.31s
# Epoch: 1560, L_clip: -0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.70, Time elapsed: 60.72s
# Epoch: 1570, L_clip: -0.11, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.90, Time elapsed: 61.11s
# Epoch: 1580, L_clip: -0.00, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.80, Time elapsed: 61.50s
# Epoch: 1590, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.80, Time elapsed: 61.88s
# Epoch: 1600, L_clip: 0.00, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.70, Time elapsed: 62.29s
# Epoch: 1610, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.50, Time elapsed: 62.70s
# Epoch: 1620, L_clip: -0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.20, Time elapsed: 63.14s
# Epoch: 1630, L_clip: -0.13, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.90, Time elapsed: 63.52s
# Epoch: 1640, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.90, Time elapsed: 63.97s
# Epoch: 1650, L_clip: 0.10, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.50, Time elapsed: 64.38s
# Epoch: 1660, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.60, Time elapsed: 64.76s
# Epoch: 1670, L_clip: 0.08, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.10, Time elapsed: 65.21s
# Epoch: 1680, L_clip: -0.14, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.90, Time elapsed: 65.58s
# Epoch: 1690, L_clip: 0.07, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.70, Time elapsed: 65.96s
# Epoch: 1700, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.40, Time elapsed: 66.36s
# Epoch: 1710, L_clip: 0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.40, Time elapsed: 66.78s
# Epoch: 1720, L_clip: -0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.40, Time elapsed: 67.20s
# Epoch: 1730, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.20, Time elapsed: 67.63s
# Epoch: 1740, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.30, Time elapsed: 68.02s
# Epoch: 1750, L_clip: -0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.50, Time elapsed: 68.41s
# Epoch: 1760, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.00, Time elapsed: 68.83s
# Epoch: 1770, L_clip: -0.06, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.60, Time elapsed: 69.21s
# Epoch: 1780, L_clip: 0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -3.80, Time elapsed: 69.68s
# Epoch: 1790, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -2.80, Time elapsed: 70.24s
# Epoch: 1800, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -1.50, Time elapsed: 70.99s
# Epoch: 1810, L_clip: -0.17, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -3.70, Time elapsed: 71.46s
# Epoch: 1820, L_clip: -0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.10, Time elapsed: 71.88s
# Epoch: 1830, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.10, Time elapsed: 72.28s
# Epoch: 1840, L_clip: 0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -3.70, Time elapsed: 72.75s
# Epoch: 1850, L_clip: 0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -1.20, Time elapsed: 73.50s
# Epoch: 1860, L_clip: -0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -1.80, Time elapsed: 74.20s
# Epoch: 1870, L_clip: 0.19, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 6.40, Time elapsed: 75.81s
# Epoch: 1880, L_clip: -0.21, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -1.00, Time elapsed: 76.62s
# Epoch: 1890, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -3.00, Time elapsed: 77.23s
# Epoch: 1900, L_clip: 0.10, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 0.80, Time elapsed: 78.20s
# Epoch: 1910, L_clip: 0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 3.50, Time elapsed: 79.50s
# Epoch: 1920, L_clip: -0.15, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 0.30, Time elapsed: 80.41s
# Epoch: 1930, L_clip: -0.20, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -0.90, Time elapsed: 81.24s
# Epoch: 1940, L_clip: 0.12, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -1.40, Time elapsed: 81.99s
# Epoch: 1950, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 1.90, Time elapsed: 83.08s
# Epoch: 1960, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 4.80, Time elapsed: 84.56s
# Epoch: 1970, L_clip: -0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 2.40, Time elapsed: 85.71s
# Epoch: 1980, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 0.80, Time elapsed: 86.71s
# Epoch: 1990, L_clip: 0.14, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 5.90, Time elapsed: 88.29s
# Epoch: 2000, L_clip: -0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -0.50, Time elapsed: 89.14s
# Epoch: 2010, L_clip: -0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 1.00, Time elapsed: 90.15s
# Epoch: 2020, L_clip: 0.15, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 7.40, Time elapsed: 91.92s
# Epoch: 2030, L_clip: -0.14, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 2.90, Time elapsed: 93.14s
# Epoch: 2040, L_clip: 0.12, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 3.80, Time elapsed: 94.48s
# Epoch: 2050, L_clip: 0.11, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 14.50, Time elapsed: 96.94s
# Epoch: 2060, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 29.00, Time elapsed: 101.03s
# Epoch: 2070, L_clip: 0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 37.10, Time elapsed: 106.05s
# Epoch: 2080, L_clip: -0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 43.00, Time elapsed: 111.57s
# Epoch: 2090, L_clip: 0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 11.90, Time elapsed: 113.73s
# Epoch: 2100, L_clip: -0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 6.20, Time elapsed: 115.29s
# Epoch: 2110, L_clip: 0.12, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 46.80, Time elapsed: 121.21s
# Epoch: 2120, L_clip: 0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 33.30, Time elapsed: 125.72s
# Epoch: 2130, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 70.00, Time elapsed: 134.20s
# Epoch: 2140, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 95.00, Time elapsed: 145.41s
# Epoch: 2150, L_clip: 0.03, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 107.70, Time elapsed: 157.95s
# Epoch: 2160, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 84.90, Time elapsed: 167.98s
# Epoch: 2170, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 228.70, Time elapsed: 193.97s
# Epoch: 2180, L_clip: -0.05, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 234.10, Time elapsed: 220.23s
# Epoch: 2190, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 244.30, Time elapsed: 247.42s
# Epoch: 2200, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 159.70, Time elapsed: 265.71s
# Epoch: 2210, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 353.80, Time elapsed: 305.34s
# Epoch: 2220, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 270.80, Time elapsed: 335.44s
# Epoch: 2230, L_clip: -0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 167.90, Time elapsed: 354.62s
# Epoch: 2240, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 100.20, Time elapsed: 366.41s
# Epoch: 2250, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 14.00, Time elapsed: 368.78s
# Epoch: 2260, L_clip: -0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 90.40, Time elapsed: 379.39s
# Epoch: 2270, L_clip: 0.14, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 20.30, Time elapsed: 382.46s
# Epoch: 2280, L_clip: -0.07, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 12.00, Time elapsed: 384.68s
# Epoch: 2290, L_clip: 0.09, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 58.50, Time elapsed: 391.97s
# Epoch: 2300, L_clip: 0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 172.10, Time elapsed: 411.41s
# Epoch: 2310, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 282.70, Time elapsed: 443.29s
# Epoch: 2320, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 285.60, Time elapsed: 475.20s
# Epoch: 2330, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 166.50, Time elapsed: 494.18s
# Epoch: 2340, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 310.90, Time elapsed: 528.87s
# Epoch: 2350, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 306.90, Time elapsed: 562.89s
# Epoch: 2360, L_clip: -0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 303.30, Time elapsed: 596.98s
# Epoch: 2370, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 391.20, Time elapsed: 641.49s
# Epoch: 2380, L_clip: 0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 506.20, Time elapsed: 698.76s
# Epoch: 2390, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 272.60, Time elapsed: 731.15s
# Epoch: 2400, L_clip: -0.08, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 189.10, Time elapsed: 752.93s
# Epoch: 2410, L_clip: 0.04, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 249.10, Time elapsed: 782.14s
# Epoch: 2420, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 241.20, Time elapsed: 809.10s
# Epoch: 2430, L_clip: -0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 500.00, Time elapsed: 866.07s
# Epoch: 2440, L_clip: 0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 376.40, Time elapsed: 908.41s
# Epoch: 2450, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 613.60, Time elapsed: 977.82s
# Epoch: 2460, L_clip: 0.00, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 539.20, Time elapsed: 1038.14s
# Epoch: 2470, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 417.00, Time elapsed: 1085.43s
# Epoch: 2480, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 595.00, Time elapsed: 1155.19s
# Epoch: 2490, L_clip: 0.01, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 674.70, Time elapsed: 1238.26s
# Epoch: 2500, L_clip: -0.06, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: 400.20, Time elapsed: 1288.34s
# Total layers:  3
# Layer setup: [[8, 1024], [1024, 512], [512, 2048]]
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Epoch: 100, L_clip: -0.85, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.91, Time elapsed: 4.23s
# Epoch: 200, L_clip: -0.36, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.89, Time elapsed: 8.58s
# Epoch: 300, L_clip: -0.42, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.84, Time elapsed: 12.36s
# Epoch: 400, L_clip: -0.20, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.99, Time elapsed: 15.82s
# Epoch: 500, L_clip: -0.05, Squared loss: 0.00, Entropy loss: 0.01, Avg Rewards: -4.74, Time elapsed: 19.81s
# Epoch: 600, L_clip: -0.02, Squared loss: 0.00, Entropy loss: 0.00, Avg Rewards: -4.77, Time elapsed: 23.46s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 16
#      13 model = PPO_Flappy(total_layers,layer_specs)
#      14 optimizer = torch.optim.Adam(model.parameters(),lr = lr)
# ---> 16 stats = Train_Network(epochs,print_freq)
#      18 # Saving model weights
#      19 #model_name = model_names[i]
#      20 #torch.save(model.state_dict(),model_name)
#
# Cell In[11], line 63, in Train_Network(epochs, print_freq)
#      58 A, returns = get_Advantage(states,rewards)
#      61 for j in range(K_epochs):
# ---> 63     action_probs,new_values = model(states) # Generate new actions and values
#      64     new_dist = torch.distributions.Categorical(action_probs) # Create distribution from new actions probs
#      65     new_policy = new_dist.log_prob(actions) # New policy probs of prev actions
#
# File ~/Documents/PPO Games/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PPO Games/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# Cell In[3], line 18, in PPO_Flappy.forward(self, x)
#      15 def forward(self,x):
#      17     for i in self.layers:
# ---> 18         x = F.tanh(i(x))
#      20     action_prob = F.softmax(self.actor(x),dim=-1) # return action probability
#      21     state_value = self.critic(x) # Critic assessed state value
#
# File ~/Documents/PPO Games/.venv/lib/python3.13/site-packages/torch/nn/functional.py:2267, in tanh(input)
#    2259 def tanh(input):  # noqa: D400,D402
#    2260     r"""tanh(input) -> Tensor
#    2261
#    2262     Applies element-wise,
#    (...)   2265     See :class:`~torch.nn.Tanh` for more details.
#    2266     """
# -> 2267     return input.tanh()
#
# KeyboardInterrupt:

# %%
stats
# Out:
#       epoch  reward    L_clip      L_vf  L_entropy
# 0         1    -5.0 -3.968718  0.001519   0.006820
# 1         2    -5.0 -4.250505  0.001827   0.006657
# 2         3    -5.0 -3.752351  0.001424   0.006643
# 3         4    -5.0 -3.613642  0.001350   0.006411
# 4         5    -5.0 -3.529992  0.001277   0.006634
# ...     ...     ...       ...       ...        ...
# 2495   2496   675.0  0.136474  0.000021   0.003233
# 2496   2497  1129.0  0.061248  0.000016   0.003236
# 2497   2498  1637.0  0.003505  0.000013   0.003259
# 2498   2499   137.0 -0.171448  0.000057   0.003132
# 2499   2500   104.0 -0.154387  0.000071   0.003163
#
# [2500 rows x 5 columns]
